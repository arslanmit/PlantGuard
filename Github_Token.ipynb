# %% [markdown]
# <a href="https://colab.research.google.com/github/arslanmit/leaf-doctor-ai-bot/blob/main/Github_Token.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass
token = getpass("GitHub Personal Access Tokenınızı girin: ")
# !git clone https://{token}:x-oauth-basic@github.com/arslanmit/leaf-doctor-ai-bot.git
# Out:
# GitHub Personal Access Tokenınızı girin: ··········
# Cloning into 'leaf-doctor-ai-bot'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 2), reused 8 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 4.39 KiB | 4.39 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
